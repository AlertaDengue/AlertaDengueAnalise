# %%
import pandas as pd
import datetime
# Out:
# /usr/local/lib/python2.7/dist-packages/pytz/__init__.py:31: UserWarning: Module PIL was already imported from /usr/local/lib/python2.7/dist-packages/PIL/__init__.pyc, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# Agora carregamos os dados. A variável com que vamos trabalhar é *casosq* que representa o número de casos das últimas duas semanas.

# %%
dateparser = lambda x: datetime.datetime.strptime(x, "%d%b%Y")
dados  = pd.read_csv("dadoscomRt.csv", sep=',', header=0, index_col=3, parse_dates=True, date_parser=dateparser)
dados[:10]
# Out:
#             julian  SE    data  casos  twits  tmin  tmed  tmax  t18  t24  t28  \
# dia
# 2009-12-27      -5   0  200952      5    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-01-03       2   1  201001     20    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-01-10       9   2  201002     24    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-01-17      16   3  201003     23    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-01-24      23   4  201004     34    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-01-31      30   5  201005     38    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-02-07      37   6  201006     33    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-02-14      44   7  201007     47    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-02-21      51   8  201008     50    NaN   NaN   NaN   NaN  NaN  NaN  NaN
# 2010-02-28      58   9  201009     57    NaN   NaN   NaN   NaN  NaN  NaN  NaN
#
#             t32  mmchuva  diaschuva umin  umed  casosq        Rt
# dia
# 2009-12-27  NaN      NaN        NaN  NaN   NaN     NaN       NaN
# 2010-01-03  NaN      NaN        NaN  NaN   NaN      25       NaN
# 2010-01-10  NaN      NaN        NaN  NaN   NaN      44  1.760000
# 2010-01-17  NaN      NaN        NaN  NaN   NaN      47  1.068182
# 2010-01-24  NaN      NaN        NaN  NaN   NaN      57  1.212766
# 2010-01-31  NaN      NaN        NaN  NaN   NaN      72  1.263158
# 2010-02-07  NaN      NaN        NaN  NaN   NaN      71  0.986111
# 2010-02-14  NaN      NaN        NaN  NaN   NaN      80  1.126761
# 2010-02-21  NaN      NaN        NaN  NaN   NaN      97  1.212500
# 2010-02-28  NaN      NaN        NaN  NaN   NaN     107  1.103093

# %%
dados.describe()
# Out:
#             julian          SE           data        casos        twits  \
# count   209.000000  209.000000     209.000000   209.000000   152.000000
# mean    723.000000  104.000000  201175.425837  1079.732057   209.848684
# std     423.340879   60.477268     113.870099  1773.209862   226.803026
# min      -5.000000    0.000000  200952.000000     3.000000    42.000000
# 25%     359.000000   52.000000  201052.000000    57.000000    70.750000
# 50%     723.000000  104.000000  201152.000000   181.000000   102.000000
# 75%    1087.000000  156.000000  201252.000000  1250.000000   245.000000
# max    1451.000000  208.000000  201352.000000  8535.000000  1369.000000
#
#              tmin        tmed        tmax         t18         t24         t28  \
# count  135.000000  149.000000  149.000000  149.000000  149.000000  149.000000
# mean    21.676753   25.705311   36.627953    6.621149    4.088711    1.968115
# std      2.794018    2.960726    3.825596    0.533522    1.755195    1.332359
# min     14.285357   18.239383   28.167500    3.177083    0.355903    0.029514
# 25%     19.756786   23.617660   33.520000    6.496528    2.678819    0.930556
# 50%     21.430357   25.359815   36.717500    6.805556    3.799479    1.595486
# 75%     23.965268   27.760230   39.985000    6.934028    5.612847    2.782986
# max     27.248214   32.137098   44.750000    7.000000    6.985243    5.782986
#
#               t32     mmchuva   diaschuva        umed        casosq  \
# count  149.000000  149.000000  149.000000  149.000000    208.000000
# mean     0.800813   21.384312    0.207850   74.099551   2169.807692
# std      0.776723   23.531576    0.191591    5.778891   3532.630139
# min      0.000000    0.000000    0.000000   58.350572     25.000000
# 25%      0.157986    5.150000    0.052951   69.828784    117.750000
# 50%      0.609375   13.000000    0.160590   74.876817    373.000000
# 75%      1.210938   29.175000    0.315972   78.512873   2420.250000
# max      3.158854  133.325000    1.024306   86.506291  16780.000000
#
#                Rt        rtml       rtmle
# count  207.000000  207.000000  209.000000
# mean     1.026321    1.029952    1.020096
# std      0.231674    0.235804    0.255286
# min      0.321839    0.300000    0.000000
# 25%      0.855099    0.900000    0.800000
# 50%      1.023529    1.000000    1.000000
# 75%      1.167004    1.200000    1.200000
# max      1.958559    2.000000    2.000000

# %%
j = dados['casosq'][1:]
j
# Out:
# dia
# 2010-01-03     25
# 2010-01-10     44
# 2010-01-17     47
# 2010-01-24     57
# 2010-01-31     72
# 2010-02-07     71
# 2010-02-14     80
# 2010-02-21     97
# 2010-02-28    107
# 2010-03-07    102
# 2010-03-14     92
# 2010-03-21    117
# 2010-03-28    115
# 2010-04-04     86
# 2010-04-11     91
# ...
# 2013-09-15     89
# 2013-09-22     96
# 2013-09-29     99
# 2013-10-06     85
# 2013-10-13     88
# 2013-10-20    101
# 2013-10-27    107
# 2013-11-03     89
# 2013-11-10     80
# 2013-11-17    105
# 2013-11-24    149
# 2013-12-01    173
# 2013-12-08    149
# 2013-12-15     87
# 2013-12-22     28
# Name: casosq, Length: 208, dtype: float64

# %% [markdown]
# A função de verossimilhança é:
#
# $$l = \prod_{k=1}^{K-1}(R_k J_k)^{J_{k+1}} e^{-R_k*J_K}$$
#
# logo a log-verossimilhança é:
#
# $$L = \sum_{k=1}^{K-1} (log(J_k)+log(R_k))J_{k+1}−J_k R_k$$

# %%
def lik_R_t(r, K):
    """
    Log-verossimilhança de r[k]
    :param r: lista com rs anteriores
    :param K: número de semanas 
    """
    L = 0
    for k in range(K):
        L += (log(j[k])+log(r[k]))*j[k+1] - j[k]*r[k]
    return L

# %% [markdown]
# Let's calculate the likelihood of $r_t$ between 0 and 5

# %%
r_support = arange(0,6,0.01)
r1 = [lik_R_t([r],1) for r in r_support]

# %%
plot(r_support,exp(r1));
title(u"Verossimilhança de $R_1$");
r1_mle = r_support[r1.index(max(r1))]
plot(r1_mle, exp(max(r1)),'ro');
grid();
xlabel(r'$R_1 = {}$'.format(r1_mle));

# %%
r2 = [lik_R_t([r1_mle,r],2) for r in r_support]
r2_mle = r_support[r2.index(max(r2))]
plot(r_support,exp(r2));
plot(r2_mle, exp(max(r2)),'ro');
title(u"Verossimilhança de $R_2$");
grid()
xlabel(r'$\hat{R}_2 = %s$'%r2_mle);

# %%
rhats = [r1,r2]
for k in range(3,len(j)):
    past_rs = [r_support[rhat.index(max(rhat))] for rhat in rhats]
    rhats.append([lik_R_t(past_rs+[r],k) for r in r_support])

# %% [markdown]
# Vamos agora compara as estimativas de $R_t$ via Maxima Verossimilhança com o método do artigo:

# %%
dados['rtmle'] = [0,0]+[r_support[rhat.index(max(rhat))] for rhat in rhats]
dados.rtmle[2:].plot(label="rtmle")
dados.Rt[2:].plot("$R_t$");
legend()
len([r_support[rhat.index(max(rhat))] for rhat in rhats])
# Out:
# 207

# %%
plot(dados.Rt[2:],dados.rtmle[2:], '*');

# %% [markdown]
# ##Calculating the 95% intervals
# For this, we must normalize the likelihood functions, so that they integrate to one, and find the confidence bands using cumsum.

# %%
def conf_band(pdf, band=.95):
    #pdf  = pdf[2:]/nansum(pdf[2:])
    pdf = exp(pdf)
    pdf /= sum(pdf)
    cdf = cumsum(pdf)
    lb = abs(0.025 - cdf)
    ub = abs(0.975 - cdf)
    #print pdf,lb, cdf
    l = r_support[2:][lb.tolist().index(nanmin(lb))]
    u = r_support[2:][ub.tolist().index(nanmin(ub))]
    return l,u

# %%
bands = array([conf_band(r) for r in rhats])
bands
# Out:
# array([[ 1.33,  2.38],
#        [ 0.82,  1.44],
#        [ 0.95,  1.59],
#        [ 1.02,  1.61],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02],
#        [ 0.02,  0.02]])

# %%
t=3
n = rhats[t][2:]
plot(r_support[2:],exp(n));
#plot(r_support[1:],n);

# %%
nansum(rhats[t][2:])
# Out:
# 363441.38527419954

# %%
en = exp(n)
enn = en/sum(en)
acu = cumsum(enn)
#acu

# %%
lb = abs(0.025-acu)
r_support[lb.tolist().index(nanmin(lb))]
# Out:
# 0.97999999999999998

# %%
ub = abs(0.975-acu)
r_support[ub.tolist().index(nanmin(ub))]
# Out:
# 1.5700000000000001
